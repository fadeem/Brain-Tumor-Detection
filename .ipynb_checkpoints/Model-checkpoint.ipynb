# %%
from rfdetr import RFDETRSmall
import json
import torch
from PIL import Image, ImageDraw, ImageFont

# %%
# --- TRAINING ---

# Initialize model (small variant)
model = RFDETRSmall()

# Optional: capture training metrics
history = []
def on_epoch_end(data):
    history.append(data)

model.callbacks["on_fit_epoch_end"].append(on_epoch_end)

# Train model
model.train(
    dataset_dir="./dataset/brain_tumor",  # directory containing COCO dataset (train/val structure)
    epochs=100,
    batch_size=16,
    lr=1e-4,
)

# Save the model checkpoint
model.save("rf_detr_small_coco.pt")

# Save training history (loss, metrics, etc.)
with open("rf_detr_small_history.json", "w") as f:
    json.dump(history, f, indent=2)

print("✅ Training complete. Model and history saved.")
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=5, grad_accum_steps=4, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=16, weight_decay=0.0001, epochs=100, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-small.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='./dataset/brain_tumor', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=512, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=32, mask_downsample_ratio=4, tensorboard=True, wandb=False, project=None, run=None, class_names=['Glioma', 'Meningioma', 'No Tumor', 'Pituitary'], run_test=True, segmentation_head=False, distributed=False)
# number of params: 31801742
# [672]
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [672]
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# [672]
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  4
# Total batch size:  64
# LENGTH OF DATA LOADER: 114
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:4316.)
# Epoch: [0]  [  0/114]  eta: 0:56:49  lr: 0.000100  class_error: 62.44  loss: 8.3429 (8.3429)  loss_ce: 1.0784 (1.0784)  loss_bbox: 0.3439 (0.3439)  loss_giou: 0.6310 (0.6310)  loss_ce_0: 1.0802 (1.0802)  loss_bbox_0: 0.3719 (0.3719)  loss_giou_0: 0.6238 (0.6238)  loss_ce_1: 1.0725 (1.0725)  loss_bbox_1: 0.3703 (0.3703)  loss_giou_1: 0.6321 (0.6321)  loss_ce_enc: 1.0389 (1.0389)  loss_bbox_enc: 0.4517 (0.4517)  loss_giou_enc: 0.6482 (0.6482)  loss_ce_unscaled: 1.0784 (1.0784)  class_error_unscaled: 62.4434 (62.4434)  loss_bbox_unscaled: 0.0688 (0.0688)  loss_giou_unscaled: 0.3155 (0.3155)  cardinality_error_unscaled: 3895.5000 (3895.5000)  loss_ce_0_unscaled: 1.0802 (1.0802)  loss_bbox_0_unscaled: 0.0744 (0.0744)  loss_giou_0_unscaled: 0.3119 (0.3119)  cardinality_error_0_unscaled: 3898.3750 (3898.3750)  loss_ce_1_unscaled: 1.0725 (1.0725)  loss_bbox_1_unscaled: 0.0741 (0.0741)  loss_giou_1_unscaled: 0.3161 (0.3161)  cardinality_error_1_unscaled: 3893.5000 (3893.5000)  loss_ce_enc_unscaled: 1.0389 (1.0389)  loss_bbox_enc_unscaled: 0.0903 (0.0903)  loss_giou_enc_unscaled: 0.3241 (0.3241)  cardinality_error_enc_unscaled: 3892.6250 (3892.6250)  time: 29.9091  data: 25.7830  max mem: 9872

# %%
#plot the graphs
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

plt.figure(figsize=(12, 8))

plt.plot(
	df['epoch'],
	df['train_loss'],
	label='Training Loss',
	marker='o',
	linestyle='-'
)

plt.plot(
	df['epoch'],
	df['test_loss'],
	label='Validation Loss',
	marker='o',
	linestyle='--'
)

plt.title('Train/Validation Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
# --- INFERENCE / PREDICTION ---
def predict_and_save(model_path, image_path, output_path, conf_threshold=0.5):
    # Load model
    model = RFDETRSmall()
    model.load(model_path)

    # Run prediction
    preds = model.predict(image_path, threshold=conf_threshold)

    # Draw predictions on image
    image = Image.open(image_path).convert("RGB")
    draw = ImageDraw.Draw(image)
    try:
        font = ImageFont.truetype("arial.ttf", 14)
    except IOError:
        font = ImageFont.load_default()

    for box, score, label in zip(preds["boxes"], preds["scores"], preds["labels"]):
        x1, y1, x2, y2 = box
        cls_name = preds["class_names"][label]
        caption = f"{cls_name} {score:.2f}"

        draw.rectangle([x1, y1, x2, y2], outline="red", width=2)
        draw.text((x1, y1 - 12), caption, fill="yellow", font=font)

    image.save(output_path)
    print(f"✅ Saved prediction image with boxes: {output_path}")

# Example usage
predict_and_save(
    model_path="rf_detr_small_coco.pt",
    image_path="sample.jpg",
    output_path="predicted_sample.jpg",
    conf_threshold=0.5
)

# %%
from rfdetr import RFDETRSmall
import json
import os

# %%
dataset_dir = "./dataset/brain_tumor"
checkpoint_path = "./output/checkpoint.pth"
target_epochs = 100
batch_size = 16
lr = 1e-4

# Instantiate model
model = RFDETRSmall()

# Prepare history list
history = []

# Callback on epoch end (supported)
def on_epoch_end(data):
    history.append(data)
    # Save after every epoch so we don't lose data
    with open("rf_detr_small_history.json", "w") as f:
        json.dump(history, f, indent=2)

# Callback on training end (supported)
def on_train_end():
    with open("rf_detr_small_history.json", "w") as f:
        json.dump(history, f, indent=2)

# Attach callbacks
model.callbacks["on_fit_epoch_end"].append(on_epoch_end)
model.callbacks["on_train_end"].append(on_train_end)

# Now train / resume
model.train(
    dataset_dir=dataset_dir,
    epochs=target_epochs,
    batch_size=batch_size,
    lr=lr,
    resume=checkpoint_path  # pass checkpoint to resume
)

# Finally, save model
model.save("rf_detr_small_resumed_final.pt")
print("✅ Training (resumed / fresh) done.")
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=5, grad_accum_steps=4, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=16, weight_decay=0.0001, epochs=100, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-small.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='./dataset/brain_tumor', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='./output/checkpoint.pth', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=512, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=32, mask_downsample_ratio=4, tensorboard=True, wandb=False, project=None, run=None, class_names=['Glioma', 'Meningioma', 'No Tumor', 'Pituitary'], run_test=True, segmentation_head=False, distributed=False)
# number of params: 31801742
# [672]
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [672]
# loading annotations into memory...
# Done (t=0.14s)
# creating index...
# index created!
# [672]
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  4
# Total batch size:  64
# LENGTH OF DATA LOADER: 114
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:4316.)
# Epoch: [66]  [  0/114]  eta: 1:39:28  lr: 0.000100  class_error: 0.00  loss: 2.4040 (2.4040)  loss_ce: 0.2875 (0.2875)  loss_bbox: 0.1014 (0.1014)  loss_giou: 0.1697 (0.1697)  loss_ce_0: 0.3585 (0.3585)  loss_bbox_0: 0.0977 (0.0977)  loss_giou_0: 0.1752 (0.1752)  loss_ce_1: 0.2982 (0.2982)  loss_bbox_1: 0.1034 (0.1034)  loss_giou_1: 0.1723 (0.1723)  loss_ce_enc: 0.3457 (0.3457)  loss_bbox_enc: 0.1148 (0.1148)  loss_giou_enc: 0.1798 (0.1798)  loss_ce_unscaled: 0.2875 (0.2875)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0203 (0.0203)  loss_giou_unscaled: 0.0848 (0.0848)  cardinality_error_unscaled: 3649.9375 (3649.9375)  loss_ce_0_unscaled: 0.3585 (0.3585)  loss_bbox_0_unscaled: 0.0195 (0.0195)  loss_giou_0_unscaled: 0.0876 (0.0876)  cardinality_error_0_unscaled: 3342.3125 (3342.3125)  loss_ce_1_unscaled: 0.2982 (0.2982)  loss_bbox_1_unscaled: 0.0207 (0.0207)  loss_giou_1_unscaled: 0.0861 (0.0861)  cardinality_error_1_unscaled: 3420.0000 (3420.0000)  loss_ce_enc_unscaled: 0.3457 (0.3457)  loss_bbox_enc_unscaled: 0.0230 (0.0230)  loss_giou_enc_unscaled: 0.0899 (0.0899)  cardinality_error_enc_unscaled: 3385.0625 (3385.0625)  time: 52.3550  data: 33.7440  max mem: 12894
# Epoch: [66]  [ 10/114]  eta: 0:12:38  lr: 0.000100  class_error: 0.00  loss: 2.5053 (2.4870)  loss_ce: 0.2975 (0.2957)  loss_bbox: 0.1108 (0.1138)  loss_giou: 0.1681 (0.1720)  loss_ce_0: 0.3125 (0.3125)  loss_bbox_0: 0.1133 (0.1168)  loss_giou_0: 0.1742 (0.1775)  loss_ce_1: 0.2982 (0.3002)  loss_bbox_1: 0.1090 (0.1138)  loss_giou_1: 0.1698 (0.1724)  loss_ce_enc: 0.3537 (0.3555)  loss_bbox_enc: 0.1463 (0.1510)  loss_giou_enc: 0.2048 (0.2057)  loss_ce_unscaled: 0.2975 (0.2957)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0222 (0.0228)  loss_giou_unscaled: 0.0841 (0.0860)  cardinality_error_unscaled: 3753.0000 (3755.6193)  loss_ce_0_unscaled: 0.3125 (0.3125)  loss_bbox_0_unscaled: 0.0227 (0.0234)  loss_giou_0_unscaled: 0.0871 (0.0888)  cardinality_error_0_unscaled: 3513.6250 (3506.6080)  loss_ce_1_unscaled: 0.2982 (0.3002)  loss_bbox_1_unscaled: 0.0218 (0.0228)  loss_giou_1_unscaled: 0.0849 (0.0862)  cardinality_error_1_unscaled: 3612.1875 (3574.4034)  loss_ce_enc_unscaled: 0.3537 (0.3555)  loss_bbox_enc_unscaled: 0.0293 (0.0302)  loss_giou_enc_unscaled: 0.1024 (0.1028)  cardinality_error_enc_unscaled: 3588.8750 (3617.1307)  time: 7.2960  data: 3.0816  max mem: 12894
# Epoch: [66]  [ 20/114]  eta: 0:08:01  lr: 0.000100  class_error: 0.00  loss: 2.4100 (2.3954)  loss_ce: 0.2876 (0.2888)  loss_bbox: 0.0849 (0.1000)  loss_giou: 0.1678 (0.1651)  loss_ce_0: 0.3036 (0.3058)  loss_bbox_0: 0.0910 (0.1031)  loss_giou_0: 0.1722 (0.1703)  loss_ce_1: 0.2913 (0.2919)  loss_bbox_1: 0.0856 (0.1007)  loss_giou_1: 0.1692 (0.1660)  loss_ce_enc: 0.3614 (0.3566)  loss_bbox_enc: 0.1422 (0.1413)  loss_giou_enc: 0.2029 (0.2057)  loss_ce_unscaled: 0.2876 (0.2888)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0170 (0.0200)  loss_giou_unscaled: 0.0839 (0.0826)  cardinality_error_unscaled: 3743.5000 (3741.9107)  loss_ce_0_unscaled: 0.3036 (0.3058)  loss_bbox_0_unscaled: 0.0182 (0.0206)  loss_giou_0_unscaled: 0.0861 (0.0852)  cardinality_error_0_unscaled: 3476.7500 (3460.9256)  loss_ce_1_unscaled: 0.2913 (0.2919)  loss_bbox_1_unscaled: 0.0171 (0.0201)  loss_giou_1_unscaled: 0.0846 (0.0830)  cardinality_error_1_unscaled: 3532.8125 (3525.0774)  loss_ce_enc_unscaled: 0.3614 (0.3566)  loss_bbox_enc_unscaled: 0.0284 (0.0283)  loss_giou_enc_unscaled: 0.1015 (0.1029)  cardinality_error_enc_unscaled: 3575.0625 (3529.2946)  time: 2.7616  data: 0.0184  max mem: 12894
# Epoch: [66]  [ 30/114]  eta: 0:06:03  lr: 0.000100  class_error: 0.00  loss: 2.3166 (2.4147)  loss_ce: 0.2730 (0.2871)  loss_bbox: 0.0895 (0.1026)  loss_giou: 0.1486 (0.1656)  loss_ce_0: 0.3036 (0.3072)  loss_bbox_0: 0.0936 (0.1050)  loss_giou_0: 0.1512 (0.1701)  loss_ce_1: 0.2809 (0.2905)  loss_bbox_1: 0.0895 (0.1034)  loss_giou_1: 0.1486 (0.1667)  loss_ce_enc: 0.3582 (0.3601)  loss_bbox_enc: 0.1425 (0.1466)  loss_giou_enc: 0.2139 (0.2099)  loss_ce_unscaled: 0.2730 (0.2871)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0179 (0.0205)  loss_giou_unscaled: 0.0743 (0.0828)  cardinality_error_unscaled: 3719.8125 (3736.1976)  loss_ce_0_unscaled: 0.3036 (0.3072)  loss_bbox_0_unscaled: 0.0187 (0.0210)  loss_giou_0_unscaled: 0.0756 (0.0851)  cardinality_error_0_unscaled: 3421.0000 (3428.7560)  loss_ce_1_unscaled: 0.2809 (0.2905)  loss_bbox_1_unscaled: 0.0179 (0.0207)  loss_giou_1_unscaled: 0.0743 (0.0833)  cardinality_error_1_unscaled: 3430.0000 (3493.9113)  loss_ce_enc_unscaled: 0.3582 (0.3601)  loss_bbox_enc_unscaled: 0.0285 (0.0293)  loss_giou_enc_unscaled: 0.1070 (0.1049)  cardinality_error_enc_unscaled: 3438.0625 (3499.7863)  time: 2.6963  data: 0.0240  max mem: 12894
# Epoch: [66]  [ 40/114]  eta: 0:04:48  lr: 0.000100  class_error: 0.00  loss: 2.3393 (2.4141)  loss_ce: 0.2674 (0.2861)  loss_bbox: 0.0927 (0.1005)  loss_giou: 0.1498 (0.1653)  loss_ce_0: 0.2983 (0.3042)  loss_bbox_0: 0.0943 (0.1029)  loss_giou_0: 0.1555 (0.1705)  loss_ce_1: 0.2836 (0.2885)  loss_bbox_1: 0.0939 (0.1016)  loss_giou_1: 0.1532 (0.1676)  loss_ce_enc: 0.3582 (0.3627)  loss_bbox_enc: 0.1480 (0.1465)  loss_giou_enc: 0.2321 (0.2178)  loss_ce_unscaled: 0.2674 (0.2861)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0185 (0.0201)  loss_giou_unscaled: 0.0749 (0.0826)  cardinality_error_unscaled: 3711.8125 (3730.7363)  loss_ce_0_unscaled: 0.2983 (0.3042)  loss_bbox_0_unscaled: 0.0189 (0.0206)  loss_giou_0_unscaled: 0.0777 (0.0853)  cardinality_error_0_unscaled: 3306.0000 (3385.7485)  loss_ce_1_unscaled: 0.2836 (0.2885)  loss_bbox_1_unscaled: 0.0188 (0.0203)  loss_giou_1_unscaled: 0.0766 (0.0838)  cardinality_error_1_unscaled: 3401.3125 (3471.2576)  loss_ce_enc_unscaled: 0.3582 (0.3627)  loss_bbox_enc_unscaled: 0.0296 (0.0293)  loss_giou_enc_unscaled: 0.1160 (0.1089)  cardinality_error_enc_unscaled: 3452.7500 (3482.9497)  time: 2.6257  data: 0.0220  max mem: 12894
# Epoch: [66]  [ 50/114]  eta: 0:03:54  lr: 0.000100  class_error: 0.00  loss: 2.4221 (2.4363)  loss_ce: 0.2842 (0.2879)  loss_bbox: 0.0925 (0.1018)  loss_giou: 0.1632 (0.1667)  loss_ce_0: 0.2948 (0.3043)  loss_bbox_0: 0.0954 (0.1040)  loss_giou_0: 0.1614 (0.1707)  loss_ce_1: 0.2872 (0.2900)  loss_bbox_1: 0.0939 (0.1026)  loss_giou_1: 0.1566 (0.1683)  loss_ce_enc: 0.3770 (0.3678)  loss_bbox_enc: 0.1481 (0.1503)  loss_giou_enc: 0.2438 (0.2220)  loss_ce_unscaled: 0.2842 (0.2879)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0185 (0.0204)  loss_giou_unscaled: 0.0816 (0.0833)  cardinality_error_unscaled: 3699.3750 (3728.5699)  loss_ce_0_unscaled: 0.2948 (0.3043)  loss_bbox_0_unscaled: 0.0191 (0.0208)  loss_giou_0_unscaled: 0.0807 (0.0853)  cardinality_error_0_unscaled: 3315.7500 (3379.0797)  loss_ce_1_unscaled: 0.2872 (0.2900)  loss_bbox_1_unscaled: 0.0188 (0.0205)  loss_giou_1_unscaled: 0.0783 (0.0842)  cardinality_error_1_unscaled: 3460.3750 (3473.5208)  loss_ce_enc_unscaled: 0.3770 (0.3678)  loss_bbox_enc_unscaled: 0.0296 (0.0301)  loss_giou_enc_unscaled: 0.1219 (0.1110)  cardinality_error_enc_unscaled: 3516.7500 (3496.6605)  time: 2.6217  data: 0.0196  max mem: 12894
# Epoch: [66]  [ 60/114]  eta: 0:03:08  lr: 0.000100  class_error: 0.00  loss: 2.6279 (2.5060)  loss_ce: 0.2971 (0.2904)  loss_bbox: 0.1121 (0.1045)  loss_giou: 0.1790 (0.1697)  loss_ce_0: 0.2948 (0.3068)  loss_bbox_0: 0.1102 (0.1068)  loss_giou_0: 0.1805 (0.1740)  loss_ce_1: 0.2969 (0.2925)  loss_bbox_1: 0.1044 (0.1051)  loss_giou_1: 0.1796 (0.1713)  loss_ce_enc: 0.4227 (0.3839)  loss_bbox_enc: 0.1795 (0.1612)  loss_giou_enc: 0.2451 (0.2401)  loss_ce_unscaled: 0.2971 (0.2904)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0224 (0.0209)  loss_giou_unscaled: 0.0895 (0.0849)  cardinality_error_unscaled: 3729.8125 (3727.9580)  loss_ce_0_unscaled: 0.2948 (0.3068)  loss_bbox_0_unscaled: 0.0220 (0.0214)  loss_giou_0_unscaled: 0.0902 (0.0870)  cardinality_error_0_unscaled: 3398.3750 (3391.2459)  loss_ce_1_unscaled: 0.2969 (0.2925)  loss_bbox_1_unscaled: 0.0209 (0.0210)  loss_giou_1_unscaled: 0.0898 (0.0856)  cardinality_error_1_unscaled: 3526.0625 (3487.4775)  loss_ce_enc_unscaled: 0.4227 (0.3839)  loss_bbox_enc_unscaled: 0.0359 (0.0322)  loss_giou_enc_unscaled: 0.1225 (0.1200)  cardinality_error_enc_unscaled: 3572.6875 (3510.7223)  time: 2.6539  data: 0.0213  max mem: 12894
# Epoch: [66]  [ 70/114]  eta: 0:02:28  lr: 0.000100  class_error: 0.00  loss: 2.6316 (2.5157)  loss_ce: 0.2991 (0.2926)  loss_bbox: 0.1036 (0.1042)  loss_giou: 0.1790 (0.1721)  loss_ce_0: 0.3087 (0.3088)  loss_bbox_0: 0.1021 (0.1064)  loss_giou_0: 0.1890 (0.1765)  loss_ce_1: 0.3057 (0.2948)  loss_bbox_1: 0.1032 (0.1048)  loss_giou_1: 0.1796 (0.1735)  loss_ce_enc: 0.4154 (0.3843)  loss_bbox_enc: 0.1674 (0.1587)  loss_giou_enc: 0.2443 (0.2390)  loss_ce_unscaled: 0.2991 (0.2926)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0207 (0.0208)  loss_giou_unscaled: 0.0895 (0.0860)  cardinality_error_unscaled: 3714.5000 (3726.3900)  loss_ce_0_unscaled: 0.3087 (0.3088)  loss_bbox_0_unscaled: 0.0204 (0.0213)  loss_giou_0_unscaled: 0.0945 (0.0882)  cardinality_error_0_unscaled: 3420.8750 (3387.5273)  loss_ce_1_unscaled: 0.3057 (0.2948)  loss_bbox_1_unscaled: 0.0206 (0.0210)  loss_giou_1_unscaled: 0.0898 (0.0867)  cardinality_error_1_unscaled: 3558.1250 (3490.7623)  loss_ce_enc_unscaled: 0.4154 (0.3843)  loss_bbox_enc_unscaled: 0.0335 (0.0317)  loss_giou_enc_unscaled: 0.1221 (0.1195)  cardinality_error_enc_unscaled: 3490.1250 (3497.4833)  time: 2.6445  data: 0.0238  max mem: 12894
# Epoch: [66]  [ 80/114]  eta: 0:01:51  lr: 0.000100  class_error: 0.00  loss: 2.5393 (2.5116)  loss_ce: 0.3056 (0.2938)  loss_bbox: 0.0911 (0.1046)  loss_giou: 0.1763 (0.1725)  loss_ce_0: 0.3087 (0.3091)  loss_bbox_0: 0.0945 (0.1069)  loss_giou_0: 0.1805 (0.1769)  loss_ce_1: 0.3086 (0.2962)  loss_bbox_1: 0.0936 (0.1053)  loss_giou_1: 0.1746 (0.1740)  loss_ce_enc: 0.3735 (0.3811)  loss_bbox_enc: 0.1325 (0.1561)  loss_giou_enc: 0.2158 (0.2351)  loss_ce_unscaled: 0.3056 (0.2938)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0182 (0.0209)  loss_giou_unscaled: 0.0882 (0.0863)  cardinality_error_unscaled: 3725.2500 (3732.5185)  loss_ce_0_unscaled: 0.3087 (0.3091)  loss_bbox_0_unscaled: 0.0189 (0.0214)  loss_giou_0_unscaled: 0.0902 (0.0885)  cardinality_error_0_unscaled: 3345.9375 (3382.0772)  loss_ce_1_unscaled: 0.3086 (0.2962)  loss_bbox_1_unscaled: 0.0187 (0.0211)  loss_giou_1_unscaled: 0.0873 (0.0870)  cardinality_error_1_unscaled: 3535.2500 (3497.6080)  loss_ce_enc_unscaled: 0.3735 (0.3811)  loss_bbox_enc_unscaled: 0.0265 (0.0312)  loss_giou_enc_unscaled: 0.1079 (0.1176)  cardinality_error_enc_unscaled: 3426.0625 (3478.7068)  time: 2.6075  data: 0.0221  max mem: 12894
# Epoch: [66]  [ 90/114]  eta: 0:01:16  lr: 0.000100  class_error: 0.00  loss: 2.4341 (2.5081)  loss_ce: 0.3036 (0.2936)  loss_bbox: 0.1063 (0.1055)  loss_giou: 0.1754 (0.1733)  loss_ce_0: 0.3003 (0.3082)  loss_bbox_0: 0.1040 (0.1075)  loss_giou_0: 0.1728 (0.1773)  loss_ce_1: 0.3007 (0.2961)  loss_bbox_1: 0.1065 (0.1059)  loss_giou_1: 0.1727 (0.1746)  loss_ce_enc: 0.3596 (0.3786)  loss_bbox_enc: 0.1274 (0.1551)  loss_giou_enc: 0.2018 (0.2325)  loss_ce_unscaled: 0.3036 (0.2936)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0213 (0.0211)  loss_giou_unscaled: 0.0877 (0.0866)  cardinality_error_unscaled: 3819.6875 (3745.3558)  loss_ce_0_unscaled: 0.3003 (0.3082)  loss_bbox_0_unscaled: 0.0208 (0.0215)  loss_giou_0_unscaled: 0.0864 (0.0886)  cardinality_error_0_unscaled: 3465.0000 (3404.7260)  loss_ce_1_unscaled: 0.3007 (0.2961)  loss_bbox_1_unscaled: 0.0213 (0.0212)  loss_giou_1_unscaled: 0.0864 (0.0873)  cardinality_error_1_unscaled: 3649.9375 (3521.6504)  loss_ce_enc_unscaled: 0.3596 (0.3786)  loss_bbox_enc_unscaled: 0.0255 (0.0310)  loss_giou_enc_unscaled: 0.1009 (0.1162)  cardinality_error_enc_unscaled: 3528.3750 (3502.9348)  time: 2.5703  data: 0.0361  max mem: 12894
# Epoch: [66]  [100/114]  eta: 0:00:43  lr: 0.000100  class_error: 0.00  loss: 2.4494 (2.5170)  loss_ce: 0.2926 (0.2960)  loss_bbox: 0.1063 (0.1059)  loss_giou: 0.1762 (0.1742)  loss_ce_0: 0.3101 (0.3105)  loss_bbox_0: 0.1040 (0.1080)  loss_giou_0: 0.1728 (0.1779)  loss_ce_1: 0.2935 (0.2987)  loss_bbox_1: 0.1065 (0.1065)  loss_giou_1: 0.1733 (0.1754)  loss_ce_enc: 0.3596 (0.3787)  loss_bbox_enc: 0.1317 (0.1543)  loss_giou_enc: 0.2136 (0.2310)  loss_ce_unscaled: 0.2926 (0.2960)  class_error_unscaled: 0.0000 (0.0495)  loss_bbox_unscaled: 0.0213 (0.0212)  loss_giou_unscaled: 0.0881 (0.0871)  cardinality_error_unscaled: 3853.5000 (3754.1027)  loss_ce_0_unscaled: 0.3101 (0.3105)  loss_bbox_0_unscaled: 0.0208 (0.0216)  loss_giou_0_unscaled: 0.0864 (0.0889)  cardinality_error_0_unscaled: 3564.0000 (3420.7618)  loss_ce_1_unscaled: 0.2935 (0.2987)  loss_bbox_1_unscaled: 0.0213 (0.0213)  loss_giou_1_unscaled: 0.0867 (0.0877)  cardinality_error_1_unscaled: 3688.0000 (3536.7754)  loss_ce_enc_unscaled: 0.3596 (0.3787)  loss_bbox_enc_unscaled: 0.0263 (0.0309)  loss_giou_enc_unscaled: 0.1068 (0.1155)  cardinality_error_enc_unscaled: 3666.6250 (3514.8670)  time: 2.6041  data: 0.0373  max mem: 12894
# Epoch: [66]  [110/114]  eta: 0:00:12  lr: 0.000100  class_error: 0.00  loss: 2.4038 (2.5120)  loss_ce: 0.3008 (0.2964)  loss_bbox: 0.1027 (0.1059)  loss_giou: 0.1762 (0.1745)  loss_ce_0: 0.3125 (0.3108)  loss_bbox_0: 0.1036 (0.1079)  loss_giou_0: 0.1713 (0.1779)  loss_ce_1: 0.3067 (0.2990)  loss_bbox_1: 0.1027 (0.1064)  loss_giou_1: 0.1733 (0.1755)  loss_ce_enc: 0.3567 (0.3760)  loss_bbox_enc: 0.1429 (0.1530)  loss_giou_enc: 0.2136 (0.2287)  loss_ce_unscaled: 0.3008 (0.2964)  class_error_unscaled: 0.0000 (0.0450)  loss_bbox_unscaled: 0.0205 (0.0212)  loss_giou_unscaled: 0.0881 (0.0872)  cardinality_error_unscaled: 3809.0625 (3758.3238)  loss_ce_0_unscaled: 0.3125 (0.3108)  loss_bbox_0_unscaled: 0.0207 (0.0216)  loss_giou_0_unscaled: 0.0856 (0.0890)  cardinality_error_0_unscaled: 3488.6875 (3420.6802)  loss_ce_1_unscaled: 0.3067 (0.2990)  loss_bbox_1_unscaled: 0.0205 (0.0213)  loss_giou_1_unscaled: 0.0866 (0.0878)  cardinality_error_1_unscaled: 3627.0000 (3540.9842)  loss_ce_enc_unscaled: 0.3567 (0.3760)  loss_bbox_enc_unscaled: 0.0286 (0.0306)  loss_giou_enc_unscaled: 0.1068 (0.1144)  cardinality_error_enc_unscaled: 3576.6250 (3512.6954)  time: 2.6820  data: 0.0199  max mem: 12894
# Epoch: [66]  [113/114]  eta: 0:00:03  lr: 0.000100  class_error: 0.00  loss: 2.3917 (2.5062)  loss_ce: 0.3020 (0.2964)  loss_bbox: 0.1027 (0.1052)  loss_giou: 0.1678 (0.1742)  loss_ce_0: 0.3126 (0.3104)  loss_bbox_0: 0.1025 (0.1072)  loss_giou_0: 0.1733 (0.1776)  loss_ce_1: 0.3138 (0.2990)  loss_bbox_1: 0.1027 (0.1057)  loss_giou_1: 0.1711 (0.1752)  loss_ce_enc: 0.3567 (0.3755)  loss_bbox_enc: 0.1429 (0.1517)  loss_giou_enc: 0.2064 (0.2280)  loss_ce_unscaled: 0.3020 (0.2964)  class_error_unscaled: 0.0000 (0.0439)  loss_bbox_unscaled: 0.0205 (0.0210)  loss_giou_unscaled: 0.0839 (0.0871)  cardinality_error_unscaled: 3809.0625 (3760.1519)  loss_ce_0_unscaled: 0.3126 (0.3104)  loss_bbox_0_unscaled: 0.0205 (0.0214)  loss_giou_0_unscaled: 0.0866 (0.0888)  cardinality_error_0_unscaled: 3488.6875 (3425.3366)  loss_ce_1_unscaled: 0.3138 (0.2990)  loss_bbox_1_unscaled: 0.0205 (0.0211)  loss_giou_1_unscaled: 0.0856 (0.0876)  cardinality_error_1_unscaled: 3627.0000 (3545.1464)  loss_ce_enc_unscaled: 0.3567 (0.3755)  loss_bbox_enc_unscaled: 0.0286 (0.0303)  loss_giou_enc_unscaled: 0.1032 (0.1140)  cardinality_error_enc_unscaled: 3595.4375 (3517.3454)  time: 2.6488  data: 0.0199  max mem: 12894
# Epoch: [66] Total time: 0:05:54 (3.1073 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 2.3917 (2.5062)  loss_ce: 0.3020 (0.2964)  loss_bbox: 0.1027 (0.1052)  loss_giou: 0.1678 (0.1742)  loss_ce_0: 0.3126 (0.3104)  loss_bbox_0: 0.1025 (0.1072)  loss_giou_0: 0.1733 (0.1776)  loss_ce_1: 0.3138 (0.2990)  loss_bbox_1: 0.1027 (0.1057)  loss_giou_1: 0.1711 (0.1752)  loss_ce_enc: 0.3567 (0.3755)  loss_bbox_enc: 0.1429 (0.1517)  loss_giou_enc: 0.2064 (0.2280)  loss_ce_unscaled: 0.3020 (0.2964)  class_error_unscaled: 0.0000 (0.0439)  loss_bbox_unscaled: 0.0205 (0.0210)  loss_giou_unscaled: 0.0839 (0.0871)  cardinality_error_unscaled: 3809.0625 (3760.1519)  loss_ce_0_unscaled: 0.3126 (0.3104)  loss_bbox_0_unscaled: 0.0205 (0.0214)  loss_giou_0_unscaled: 0.0866 (0.0888)  cardinality_error_0_unscaled: 3488.6875 (3425.3366)  loss_ce_1_unscaled: 0.3138 (0.2990)  loss_bbox_1_unscaled: 0.0205 (0.0211)  loss_giou_1_unscaled: 0.0856 (0.0876)  cardinality_error_1_unscaled: 3627.0000 (3545.1464)  loss_ce_enc_unscaled: 0.3567 (0.3755)  loss_bbox_enc_unscaled: 0.0286 (0.0303)  loss_giou_enc_unscaled: 0.1032 (0.1140)  cardinality_error_enc_unscaled: 3595.4375 (3517.3454)
# Test:  [ 0/68]  eta: 0:28:31  class_error: 0.00  loss: 4.6134 (4.6134)  loss_ce: 0.5625 (0.5625)  loss_bbox: 0.1992 (0.1992)  loss_giou: 0.4027 (0.4027)  loss_ce_0: 0.5430 (0.5430)  loss_bbox_0: 0.1965 (0.1965)  loss_giou_0: 0.3987 (0.3987)  loss_ce_1: 0.5469 (0.5469)  loss_bbox_1: 0.1992 (0.1992)  loss_giou_1: 0.4022 (0.4022)  loss_ce_enc: 0.6328 (0.6328)  loss_bbox_enc: 0.1565 (0.1565)  loss_giou_enc: 0.3732 (0.3732)  loss_ce_unscaled: 0.5625 (0.5625)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0398 (0.0398)  loss_giou_unscaled: 0.2013 (0.2013)  cardinality_error_unscaled: 292.6250 (292.6250)  loss_ce_0_unscaled: 0.5430 (0.5430)  loss_bbox_0_unscaled: 0.0393 (0.0393)  loss_giou_0_unscaled: 0.1993 (0.1993)  cardinality_error_0_unscaled: 265.3750 (265.3750)  loss_ce_1_unscaled: 0.5469 (0.5469)  loss_bbox_1_unscaled: 0.0398 (0.0398)  loss_giou_1_unscaled: 0.2011 (0.2011)  cardinality_error_1_unscaled: 280.8125 (280.8125)  loss_ce_enc_unscaled: 0.6328 (0.6328)  loss_bbox_enc_unscaled: 0.0313 (0.0313)  loss_giou_enc_unscaled: 0.1866 (0.1866)  cardinality_error_enc_unscaled: 272.2500 (272.2500)  time: 25.1727  data: 24.3144  max mem: 12894
# Test:  [10/68]  eta: 0:02:31  class_error: 0.00  loss: 3.3860 (3.3834)  loss_ce: 0.3945 (0.4274)  loss_bbox: 0.1095 (0.1200)  loss_giou: 0.2773 (0.2814)  loss_ce_0: 0.3965 (0.4233)  loss_bbox_0: 0.1202 (0.1232)  loss_giou_0: 0.2859 (0.2886)  loss_ce_1: 0.3984 (0.4309)  loss_bbox_1: 0.1139 (0.1213)  loss_giou_1: 0.2855 (0.2835)  loss_ce_enc: 0.4395 (0.4565)  loss_bbox_enc: 0.1264 (0.1299)  loss_giou_enc: 0.3127 (0.2974)  loss_ce_unscaled: 0.3945 (0.4274)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0219 (0.0240)  loss_giou_unscaled: 0.1386 (0.1407)  cardinality_error_unscaled: 293.3750 (293.7102)  loss_ce_0_unscaled: 0.3965 (0.4233)  loss_bbox_0_unscaled: 0.0240 (0.0246)  loss_giou_0_unscaled: 0.1430 (0.1443)  cardinality_error_0_unscaled: 266.6250 (268.9773)  loss_ce_1_unscaled: 0.3984 (0.4309)  loss_bbox_1_unscaled: 0.0228 (0.0243)  loss_giou_1_unscaled: 0.1428 (0.1418)  cardinality_error_1_unscaled: 281.1875 (282.2955)  loss_ce_enc_unscaled: 0.4395 (0.4565)  loss_bbox_enc_unscaled: 0.0253 (0.0260)  loss_giou_enc_unscaled: 0.1564 (0.1487)  cardinality_error_enc_unscaled: 274.8750 (277.0114)  time: 2.6179  data: 2.2373  max mem: 12894
# Test:  [20/68]  eta: 0:01:14  class_error: 0.00  loss: 3.6003 (3.5607)  loss_ce: 0.3809 (0.4221)  loss_bbox: 0.1207 (0.1702)  loss_giou: 0.2773 (0.2804)  loss_ce_0: 0.3926 (0.4231)  loss_bbox_0: 0.1209 (0.1752)  loss_giou_0: 0.2807 (0.2860)  loss_ce_1: 0.3809 (0.4242)  loss_bbox_1: 0.1209 (0.1713)  loss_giou_1: 0.2764 (0.2817)  loss_ce_enc: 0.4141 (0.4482)  loss_bbox_enc: 0.1383 (0.1826)  loss_giou_enc: 0.3043 (0.2957)  loss_ce_unscaled: 0.3809 (0.4221)  class_error_unscaled: 0.0000 (0.2646)  loss_bbox_unscaled: 0.0241 (0.0340)  loss_giou_unscaled: 0.1386 (0.1402)  cardinality_error_unscaled: 293.8750 (293.9435)  loss_ce_0_unscaled: 0.3926 (0.4231)  loss_bbox_0_unscaled: 0.0242 (0.0350)  loss_giou_0_unscaled: 0.1404 (0.1430)  cardinality_error_0_unscaled: 269.7500 (271.6935)  loss_ce_1_unscaled: 0.3809 (0.4242)  loss_bbox_1_unscaled: 0.0242 (0.0343)  loss_giou_1_unscaled: 0.1382 (0.1409)  cardinality_error_1_unscaled: 283.1250 (283.2232)  loss_ce_enc_unscaled: 0.4141 (0.4482)  loss_bbox_enc_unscaled: 0.0277 (0.0365)  loss_giou_enc_unscaled: 0.1521 (0.1479)  cardinality_error_enc_unscaled: 277.9375 (279.4405)  time: 0.3809  data: 0.0292  max mem: 12894
# Test:  [30/68]  eta: 0:00:45  class_error: 0.00  loss: 3.7886 (3.6857)  loss_ce: 0.3965 (0.4432)  loss_bbox: 0.1756 (0.1687)  loss_giou: 0.2945 (0.2950)  loss_ce_0: 0.4238 (0.4455)  loss_bbox_0: 0.1798 (0.1719)  loss_giou_0: 0.3102 (0.2971)  loss_ce_1: 0.3965 (0.4445)  loss_bbox_1: 0.1734 (0.1677)  loss_giou_1: 0.3049 (0.2924)  loss_ce_enc: 0.4414 (0.4619)  loss_bbox_enc: 0.2154 (0.1859)  loss_giou_enc: 0.3183 (0.3119)  loss_ce_unscaled: 0.3965 (0.4432)  class_error_unscaled: 0.0000 (0.5303)  loss_bbox_unscaled: 0.0351 (0.0337)  loss_giou_unscaled: 0.1472 (0.1475)  cardinality_error_unscaled: 295.0000 (294.4758)  loss_ce_0_unscaled: 0.4238 (0.4455)  loss_bbox_0_unscaled: 0.0360 (0.0344)  loss_giou_0_unscaled: 0.1551 (0.1485)  cardinality_error_0_unscaled: 276.7500 (274.0827)  loss_ce_1_unscaled: 0.3965 (0.4445)  loss_bbox_1_unscaled: 0.0347 (0.0335)  loss_giou_1_unscaled: 0.1525 (0.1462)  cardinality_error_1_unscaled: 284.8125 (284.0282)  loss_ce_enc_unscaled: 0.4414 (0.4619)  loss_bbox_enc_unscaled: 0.0431 (0.0372)  loss_giou_enc_unscaled: 0.1592 (0.1559)  cardinality_error_enc_unscaled: 284.0625 (281.7359)  time: 0.3980  data: 0.0285  max mem: 12894
# Test:  [40/68]  eta: 0:00:27  class_error: 0.00  loss: 3.6986 (3.7065)  loss_ce: 0.4785 (0.4515)  loss_bbox: 0.1334 (0.1668)  loss_giou: 0.2607 (0.2904)  loss_ce_0: 0.4727 (0.4542)  loss_bbox_0: 0.1543 (0.1698)  loss_giou_0: 0.2646 (0.2931)  loss_ce_1: 0.4805 (0.4529)  loss_bbox_1: 0.1383 (0.1660)  loss_giou_1: 0.2585 (0.2885)  loss_ce_enc: 0.4902 (0.4748)  loss_bbox_enc: 0.2031 (0.1889)  loss_giou_enc: 0.2806 (0.3096)  loss_ce_unscaled: 0.4785 (0.4515)  class_error_unscaled: 0.0000 (1.1585)  loss_bbox_unscaled: 0.0267 (0.0334)  loss_giou_unscaled: 0.1304 (0.1452)  cardinality_error_unscaled: 295.8125 (294.7942)  loss_ce_0_unscaled: 0.4727 (0.4542)  loss_bbox_0_unscaled: 0.0309 (0.0340)  loss_giou_0_unscaled: 0.1323 (0.1465)  cardinality_error_0_unscaled: 282.5625 (276.0716)  loss_ce_1_unscaled: 0.4805 (0.4529)  loss_bbox_1_unscaled: 0.0277 (0.0332)  loss_giou_1_unscaled: 0.1293 (0.1443)  cardinality_error_1_unscaled: 285.6875 (284.3262)  loss_ce_enc_unscaled: 0.4902 (0.4748)  loss_bbox_enc_unscaled: 0.0406 (0.0378)  loss_giou_enc_unscaled: 0.1403 (0.1548)  cardinality_error_enc_unscaled: 287.7500 (283.5671)  time: 0.4051  data: 0.0303  max mem: 12894
# Test:  [50/68]  eta: 0:00:15  class_error: 6.25  loss: 3.4051 (3.6164)  loss_ce: 0.4316 (0.4501)  loss_bbox: 0.1221 (0.1572)  loss_giou: 0.2157 (0.2762)  loss_ce_0: 0.4277 (0.4562)  loss_bbox_0: 0.1225 (0.1598)  loss_giou_0: 0.2225 (0.2789)  loss_ce_1: 0.4277 (0.4520)  loss_bbox_1: 0.1187 (0.1564)  loss_giou_1: 0.2208 (0.2747)  loss_ce_enc: 0.5039 (0.4759)  loss_bbox_enc: 0.1545 (0.1817)  loss_giou_enc: 0.2500 (0.2973)  loss_ce_unscaled: 0.4316 (0.4501)  class_error_unscaled: 0.0000 (1.6386)  loss_bbox_unscaled: 0.0244 (0.0314)  loss_giou_unscaled: 0.1079 (0.1381)  cardinality_error_unscaled: 295.8125 (294.9032)  loss_ce_0_unscaled: 0.4277 (0.4562)  loss_bbox_0_unscaled: 0.0245 (0.0320)  loss_giou_0_unscaled: 0.1113 (0.1394)  cardinality_error_0_unscaled: 282.6250 (277.3297)  loss_ce_1_unscaled: 0.4277 (0.4520)  loss_bbox_1_unscaled: 0.0237 (0.0313)  loss_giou_1_unscaled: 0.1104 (0.1374)  cardinality_error_1_unscaled: 285.5000 (284.6483)  loss_ce_enc_unscaled: 0.5039 (0.4759)  loss_bbox_enc_unscaled: 0.0309 (0.0363)  loss_giou_enc_unscaled: 0.1250 (0.1487)  cardinality_error_enc_unscaled: 289.2500 (284.5306)  time: 0.4078  data: 0.0321  max mem: 12894
# Test:  [60/68]  eta: 0:00:06  class_error: 0.00  loss: 3.2142 (3.5784)  loss_ce: 0.4316 (0.4523)  loss_bbox: 0.1105 (0.1501)  loss_giou: 0.2337 (0.2721)  loss_ce_0: 0.4277 (0.4570)  loss_bbox_0: 0.1129 (0.1529)  loss_giou_0: 0.2346 (0.2755)  loss_ce_1: 0.4277 (0.4538)  loss_bbox_1: 0.1108 (0.1501)  loss_giou_1: 0.2352 (0.2716)  loss_ce_enc: 0.4609 (0.4757)  loss_bbox_enc: 0.1432 (0.1731)  loss_giou_enc: 0.2398 (0.2942)  loss_ce_unscaled: 0.4316 (0.4523)  class_error_unscaled: 0.0000 (1.5391)  loss_bbox_unscaled: 0.0221 (0.0300)  loss_giou_unscaled: 0.1169 (0.1361)  cardinality_error_unscaled: 296.2500 (295.1875)  loss_ce_0_unscaled: 0.4277 (0.4570)  loss_bbox_0_unscaled: 0.0226 (0.0306)  loss_giou_0_unscaled: 0.1173 (0.1378)  cardinality_error_0_unscaled: 281.0625 (277.9990)  loss_ce_1_unscaled: 0.4277 (0.4538)  loss_bbox_1_unscaled: 0.0222 (0.0300)  loss_giou_1_unscaled: 0.1176 (0.1358)  cardinality_error_1_unscaled: 287.1250 (285.1814)  loss_ce_enc_unscaled: 0.4609 (0.4757)  loss_bbox_enc_unscaled: 0.0286 (0.0346)  loss_giou_enc_unscaled: 0.1199 (0.1471)  cardinality_error_enc_unscaled: 287.9375 (285.0943)  time: 0.4141  data: 0.0313  max mem: 12894
# Test:  [67/68]  eta: 0:00:00  class_error: 0.00  loss: 3.3366 (3.6529)  loss_ce: 0.4766 (0.4598)  loss_bbox: 0.1125 (0.1527)  loss_giou: 0.2449 (0.2809)  loss_ce_0: 0.4648 (0.4645)  loss_bbox_0: 0.1189 (0.1555)  loss_giou_0: 0.2662 (0.2843)  loss_ce_1: 0.4688 (0.4613)  loss_bbox_1: 0.1180 (0.1528)  loss_giou_1: 0.2619 (0.2806)  loss_ce_enc: 0.4902 (0.4835)  loss_bbox_enc: 0.1500 (0.1737)  loss_giou_enc: 0.3029 (0.3031)  loss_ce_unscaled: 0.4766 (0.4598)  class_error_unscaled: 0.0000 (1.4940)  loss_bbox_unscaled: 0.0225 (0.0305)  loss_giou_unscaled: 0.1224 (0.1405)  cardinality_error_unscaled: 296.5000 (295.2923)  loss_ce_0_unscaled: 0.4648 (0.4645)  loss_bbox_0_unscaled: 0.0238 (0.0311)  loss_giou_0_unscaled: 0.1331 (0.1421)  cardinality_error_0_unscaled: 279.5000 (277.8438)  loss_ce_1_unscaled: 0.4688 (0.4613)  loss_bbox_1_unscaled: 0.0236 (0.0306)  loss_giou_1_unscaled: 0.1309 (0.1403)  cardinality_error_1_unscaled: 287.6250 (285.4347)  loss_ce_enc_unscaled: 0.4902 (0.4835)  loss_bbox_enc_unscaled: 0.0300 (0.0347)  loss_giou_enc_unscaled: 0.1514 (0.1516)  cardinality_error_enc_unscaled: 286.3125 (285.0726)  time: 0.4111  data: 0.0313  max mem: 12894
# Test: Total time: 0:00:53 (0.7832 s / it)
# Averaged stats: class_error: 0.00  loss: 3.3366 (3.6529)  loss_ce: 0.4766 (0.4598)  loss_bbox: 0.1125 (0.1527)  loss_giou: 0.2449 (0.2809)  loss_ce_0: 0.4648 (0.4645)  loss_bbox_0: 0.1189 (0.1555)  loss_giou_0: 0.2662 (0.2843)  loss_ce_1: 0.4688 (0.4613)  loss_bbox_1: 0.1180 (0.1528)  loss_giou_1: 0.2619 (0.2806)  loss_ce_enc: 0.4902 (0.4835)  loss_bbox_enc: 0.1500 (0.1737)  loss_giou_enc: 0.3029 (0.3031)  loss_ce_unscaled: 0.4766 (0.4598)  class_error_unscaled: 0.0000 (1.4940)  loss_bbox_unscaled: 0.0225 (0.0305)  loss_giou_unscaled: 0.1224 (0.1405)  cardinality_error_unscaled: 296.5000 (295.2923)  loss_ce_0_unscaled: 0.4648 (0.4645)  loss_bbox_0_unscaled: 0.0238 (0.0311)  loss_giou_0_unscaled: 0.1331 (0.1421)  cardinality_error_0_unscaled: 279.5000 (277.8438)  loss_ce_1_unscaled: 0.4688 (0.4613)  loss_bbox_1_unscaled: 0.0236 (0.0306)  loss_giou_1_unscaled: 0.1309 (0.1403)  cardinality_error_1_unscaled: 287.6250 (285.4347)  loss_ce_enc_unscaled: 0.4902 (0.4835)  loss_bbox_enc_unscaled: 0.0300 (0.0347)  loss_giou_enc_unscaled: 0.1514 (0.1516)  cardinality_error_enc_unscaled: 286.3125 (285.0726)
# Accumulating evaluation results...
# DONE (t=2.82s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.746
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.940
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.831
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.368
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.818
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.758
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.817
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.603
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.756
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.868
# Test:  [ 0/68]  eta: 1:13:41  class_error: 0.00  loss: 4.5481 (4.5481)  loss_ce: 0.5508 (0.5508)  loss_bbox: 0.1990 (0.1990)  loss_giou: 0.4009 (0.4009)  loss_ce_0: 0.5703 (0.5703)  loss_bbox_0: 0.1540 (0.1540)  loss_giou_0: 0.3593 (0.3593)  loss_ce_1: 0.5430 (0.5430)  loss_bbox_1: 0.1995 (0.1995)  loss_giou_1: 0.4002 (0.4002)  loss_ce_enc: 0.5703 (0.5703)  loss_bbox_enc: 0.1988 (0.1988)  loss_giou_enc: 0.4019 (0.4019)  loss_ce_unscaled: 0.5508 (0.5508)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0398 (0.0398)  loss_giou_unscaled: 0.2005 (0.2005)  cardinality_error_unscaled: 292.3125 (292.3125)  loss_ce_0_unscaled: 0.5703 (0.5703)  loss_bbox_0_unscaled: 0.0308 (0.0308)  loss_giou_0_unscaled: 0.1797 (0.1797)  cardinality_error_0_unscaled: 259.9375 (259.9375)  loss_ce_1_unscaled: 0.5430 (0.5430)  loss_bbox_1_unscaled: 0.0399 (0.0399)  loss_giou_1_unscaled: 0.2001 (0.2001)  cardinality_error_1_unscaled: 278.0000 (278.0000)  loss_ce_enc_unscaled: 0.5703 (0.5703)  loss_bbox_enc_unscaled: 0.0398 (0.0398)  loss_giou_enc_unscaled: 0.2010 (0.2010)  cardinality_error_enc_unscaled: 268.7500 (268.7500)  time: 65.0154  data: 64.3954  max mem: 12894
# Test:  [10/68]  eta: 0:06:03  class_error: 0.00  loss: 3.4048 (3.3785)  loss_ce: 0.4004 (0.4288)  loss_bbox: 0.1080 (0.1194)  loss_giou: 0.2774 (0.2802)  loss_ce_0: 0.4004 (0.4277)  loss_bbox_0: 0.1202 (0.1191)  loss_giou_0: 0.2903 (0.2846)  loss_ce_1: 0.4043 (0.4276)  loss_bbox_1: 0.1190 (0.1233)  loss_giou_1: 0.2879 (0.2864)  loss_ce_enc: 0.4336 (0.4494)  loss_bbox_enc: 0.1246 (0.1333)  loss_giou_enc: 0.3095 (0.2988)  loss_ce_unscaled: 0.4004 (0.4288)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0216 (0.0239)  loss_giou_unscaled: 0.1387 (0.1401)  cardinality_error_unscaled: 293.3125 (293.2670)  loss_ce_0_unscaled: 0.4004 (0.4277)  loss_bbox_0_unscaled: 0.0240 (0.0238)  loss_giou_0_unscaled: 0.1452 (0.1423)  cardinality_error_0_unscaled: 263.3125 (265.6591)  loss_ce_1_unscaled: 0.4043 (0.4276)  loss_bbox_1_unscaled: 0.0238 (0.0247)  loss_giou_1_unscaled: 0.1439 (0.1432)  cardinality_error_1_unscaled: 279.6250 (280.4886)  loss_ce_enc_unscaled: 0.4336 (0.4494)  loss_bbox_enc_unscaled: 0.0249 (0.0267)  loss_giou_enc_unscaled: 0.1548 (0.1494)  cardinality_error_enc_unscaled: 272.4375 (274.6932)  time: 6.2590  data: 5.8792  max mem: 12894
# Test:  [20/68]  eta: 0:02:46  class_error: 0.00  loss: 3.5971 (3.5459)  loss_ce: 0.3809 (0.4207)  loss_bbox: 0.1208 (0.1699)  loss_giou: 0.2754 (0.2795)  loss_ce_0: 0.3926 (0.4245)  loss_bbox_0: 0.1221 (0.1720)  loss_giou_0: 0.2783 (0.2829)  loss_ce_1: 0.3809 (0.4204)  loss_bbox_1: 0.1216 (0.1716)  loss_giou_1: 0.2718 (0.2826)  loss_ce_enc: 0.4219 (0.4426)  loss_bbox_enc: 0.1321 (0.1840)  loss_giou_enc: 0.3081 (0.2951)  loss_ce_unscaled: 0.3809 (0.4207)  class_error_unscaled: 0.0000 (0.2646)  loss_bbox_unscaled: 0.0242 (0.0340)  loss_giou_unscaled: 0.1377 (0.1398)  cardinality_error_unscaled: 293.3125 (293.5625)  loss_ce_0_unscaled: 0.3926 (0.4245)  loss_bbox_0_unscaled: 0.0244 (0.0344)  loss_giou_0_unscaled: 0.1391 (0.1415)  cardinality_error_0_unscaled: 265.8125 (268.7411)  loss_ce_1_unscaled: 0.3809 (0.4204)  loss_bbox_1_unscaled: 0.0243 (0.0343)  loss_giou_1_unscaled: 0.1359 (0.1413)  cardinality_error_1_unscaled: 280.9375 (281.3304)  loss_ce_enc_unscaled: 0.4219 (0.4426)  loss_bbox_enc_unscaled: 0.0264 (0.0368)  loss_giou_enc_unscaled: 0.1541 (0.1476)  cardinality_error_enc_unscaled: 275.5000 (277.4137)  time: 0.3942  data: 0.0316  max mem: 12894
# Test:  [30/68]  eta: 0:01:34  class_error: 0.00  loss: 3.8185 (3.6661)  loss_ce: 0.3926 (0.4419)  loss_bbox: 0.1622 (0.1669)  loss_giou: 0.2827 (0.2910)  loss_ce_0: 0.3926 (0.4430)  loss_bbox_0: 0.1896 (0.1698)  loss_giou_0: 0.3042 (0.2948)  loss_ce_1: 0.3945 (0.4396)  loss_bbox_1: 0.1841 (0.1687)  loss_giou_1: 0.3023 (0.2938)  loss_ce_enc: 0.4258 (0.4582)  loss_bbox_enc: 0.2136 (0.1870)  loss_giou_enc: 0.3150 (0.3112)  loss_ce_unscaled: 0.3926 (0.4419)  class_error_unscaled: 0.0000 (0.5303)  loss_bbox_unscaled: 0.0324 (0.0334)  loss_giou_unscaled: 0.1413 (0.1455)  cardinality_error_unscaled: 294.5000 (294.0726)  loss_ce_0_unscaled: 0.3926 (0.4430)  loss_bbox_0_unscaled: 0.0379 (0.0340)  loss_giou_0_unscaled: 0.1521 (0.1474)  cardinality_error_0_unscaled: 274.4375 (271.3488)  loss_ce_1_unscaled: 0.3945 (0.4396)  loss_bbox_1_unscaled: 0.0368 (0.0337)  loss_giou_1_unscaled: 0.1511 (0.1469)  cardinality_error_1_unscaled: 283.0625 (282.2036)  loss_ce_enc_unscaled: 0.4258 (0.4582)  loss_bbox_enc_unscaled: 0.0427 (0.0374)  loss_giou_enc_unscaled: 0.1575 (0.1556)  cardinality_error_enc_unscaled: 281.5625 (279.7157)  time: 0.4136  data: 0.0332  max mem: 12894
# Test:  [40/68]  eta: 0:00:55  class_error: 0.00  loss: 3.5803 (3.6802)  loss_ce: 0.4648 (0.4496)  loss_bbox: 0.1349 (0.1648)  loss_giou: 0.2526 (0.2842)  loss_ce_0: 0.4648 (0.4528)  loss_bbox_0: 0.1375 (0.1672)  loss_giou_0: 0.2637 (0.2889)  loss_ce_1: 0.4727 (0.4481)  loss_bbox_1: 0.1356 (0.1667)  loss_giou_1: 0.2569 (0.2888)  loss_ce_enc: 0.4883 (0.4708)  loss_bbox_enc: 0.2114 (0.1892)  loss_giou_enc: 0.2641 (0.3091)  loss_ce_unscaled: 0.4648 (0.4496)  class_error_unscaled: 0.0000 (1.2805)  loss_bbox_unscaled: 0.0270 (0.0330)  loss_giou_unscaled: 0.1263 (0.1421)  cardinality_error_unscaled: 295.3125 (294.3750)  loss_ce_0_unscaled: 0.4648 (0.4528)  loss_bbox_0_unscaled: 0.0275 (0.0334)  loss_giou_0_unscaled: 0.1318 (0.1445)  cardinality_error_0_unscaled: 280.3125 (273.4405)  loss_ce_1_unscaled: 0.4727 (0.4481)  loss_bbox_1_unscaled: 0.0271 (0.0333)  loss_giou_1_unscaled: 0.1284 (0.1444)  cardinality_error_1_unscaled: 283.8750 (282.4588)  loss_ce_enc_unscaled: 0.4883 (0.4708)  loss_bbox_enc_unscaled: 0.0423 (0.0378)  loss_giou_enc_unscaled: 0.1320 (0.1545)  cardinality_error_enc_unscaled: 286.5625 (281.6768)  time: 0.4276  data: 0.0307  max mem: 12894
# Test:  [50/68]  eta: 0:00:30  class_error: 0.00  loss: 3.2822 (3.5893)  loss_ce: 0.4316 (0.4477)  loss_bbox: 0.1167 (0.1550)  loss_giou: 0.2128 (0.2706)  loss_ce_0: 0.4316 (0.4556)  loss_bbox_0: 0.1164 (0.1572)  loss_giou_0: 0.2215 (0.2748)  loss_ce_1: 0.4336 (0.4474)  loss_bbox_1: 0.1166 (0.1566)  loss_giou_1: 0.2168 (0.2745)  loss_ce_enc: 0.4785 (0.4702)  loss_bbox_enc: 0.1536 (0.1820)  loss_giou_enc: 0.2567 (0.2976)  loss_ce_unscaled: 0.4316 (0.4477)  class_error_unscaled: 0.0000 (1.6141)  loss_bbox_unscaled: 0.0233 (0.0310)  loss_giou_unscaled: 0.1064 (0.1353)  cardinality_error_unscaled: 295.3750 (294.4792)  loss_ce_0_unscaled: 0.4316 (0.4556)  loss_bbox_0_unscaled: 0.0233 (0.0314)  loss_giou_0_unscaled: 0.1107 (0.1374)  cardinality_error_0_unscaled: 280.6875 (274.7966)  loss_ce_1_unscaled: 0.4336 (0.4474)  loss_bbox_1_unscaled: 0.0233 (0.0313)  loss_giou_1_unscaled: 0.1084 (0.1373)  cardinality_error_1_unscaled: 283.1875 (282.8431)  loss_ce_enc_unscaled: 0.4785 (0.4702)  loss_bbox_enc_unscaled: 0.0307 (0.0364)  loss_giou_enc_unscaled: 0.1283 (0.1488)  cardinality_error_enc_unscaled: 287.5625 (282.7819)  time: 0.4260  data: 0.0321  max mem: 12894
# Test:  [60/68]  eta: 0:00:11  class_error: 0.00  loss: 3.2822 (3.5562)  loss_ce: 0.4316 (0.4507)  loss_bbox: 0.1091 (0.1482)  loss_giou: 0.2312 (0.2671)  loss_ce_0: 0.4316 (0.4570)  loss_bbox_0: 0.1097 (0.1500)  loss_giou_0: 0.2288 (0.2713)  loss_ce_1: 0.4336 (0.4504)  loss_bbox_1: 0.1088 (0.1496)  loss_giou_1: 0.2340 (0.2706)  loss_ce_enc: 0.4434 (0.4712)  loss_bbox_enc: 0.1510 (0.1747)  loss_giou_enc: 0.2726 (0.2953)  loss_ce_unscaled: 0.4316 (0.4507)  class_error_unscaled: 0.0000 (1.5187)  loss_bbox_unscaled: 0.0218 (0.0296)  loss_giou_unscaled: 0.1156 (0.1336)  cardinality_error_unscaled: 296.0000 (294.8064)  loss_ce_0_unscaled: 0.4316 (0.4570)  loss_bbox_0_unscaled: 0.0219 (0.0300)  loss_giou_0_unscaled: 0.1144 (0.1357)  cardinality_error_0_unscaled: 278.2500 (275.4252)  loss_ce_1_unscaled: 0.4336 (0.4504)  loss_bbox_1_unscaled: 0.0218 (0.0299)  loss_giou_1_unscaled: 0.1170 (0.1353)  cardinality_error_1_unscaled: 284.8750 (283.3586)  loss_ce_enc_unscaled: 0.4434 (0.4712)  loss_bbox_enc_unscaled: 0.0302 (0.0349)  loss_giou_enc_unscaled: 0.1363 (0.1476)  cardinality_error_enc_unscaled: 285.5000 (283.2531)  time: 0.4263  data: 0.0326  max mem: 12894
# Test:  [67/68]  eta: 0:00:01  class_error: 0.00  loss: 3.3472 (3.6296)  loss_ce: 0.4883 (0.4589)  loss_bbox: 0.1098 (0.1500)  loss_giou: 0.2453 (0.2754)  loss_ce_0: 0.4688 (0.4656)  loss_bbox_0: 0.1164 (0.1518)  loss_giou_0: 0.2662 (0.2793)  loss_ce_1: 0.4785 (0.4587)  loss_bbox_1: 0.1112 (0.1515)  loss_giou_1: 0.2561 (0.2790)  loss_ce_enc: 0.4883 (0.4800)  loss_bbox_enc: 0.1510 (0.1753)  loss_giou_enc: 0.3005 (0.3041)  loss_ce_unscaled: 0.4883 (0.4589)  class_error_unscaled: 0.0000 (1.4756)  loss_bbox_unscaled: 0.0220 (0.0300)  loss_giou_unscaled: 0.1227 (0.1377)  cardinality_error_unscaled: 296.0625 (294.9301)  loss_ce_0_unscaled: 0.4688 (0.4656)  loss_bbox_0_unscaled: 0.0233 (0.0304)  loss_giou_0_unscaled: 0.1331 (0.1396)  cardinality_error_0_unscaled: 277.1875 (275.1893)  loss_ce_1_unscaled: 0.4785 (0.4587)  loss_bbox_1_unscaled: 0.0222 (0.0303)  loss_giou_1_unscaled: 0.1280 (0.1395)  cardinality_error_1_unscaled: 286.1250 (283.5928)  loss_ce_enc_unscaled: 0.4883 (0.4800)  loss_bbox_enc_unscaled: 0.0302 (0.0351)  loss_giou_enc_unscaled: 0.1503 (0.1521)  cardinality_error_enc_unscaled: 283.3125 (283.0625)  time: 0.4213  data: 0.0299  max mem: 12894
# Test: Total time: 0:01:34 (1.3844 s / it)
# Averaged stats: class_error: 0.00  loss: 3.3472 (3.6296)  loss_ce: 0.4883 (0.4589)  loss_bbox: 0.1098 (0.1500)  loss_giou: 0.2453 (0.2754)  loss_ce_0: 0.4688 (0.4656)  loss_bbox_0: 0.1164 (0.1518)  loss_giou_0: 0.2662 (0.2793)  loss_ce_1: 0.4785 (0.4587)  loss_bbox_1: 0.1112 (0.1515)  loss_giou_1: 0.2561 (0.2790)  loss_ce_enc: 0.4883 (0.4800)  loss_bbox_enc: 0.1510 (0.1753)  loss_giou_enc: 0.3005 (0.3041)  loss_ce_unscaled: 0.4883 (0.4589)  class_error_unscaled: 0.0000 (1.4756)  loss_bbox_unscaled: 0.0220 (0.0300)  loss_giou_unscaled: 0.1227 (0.1377)  cardinality_error_unscaled: 296.0625 (294.9301)  loss_ce_0_unscaled: 0.4688 (0.4656)  loss_bbox_0_unscaled: 0.0233 (0.0304)  loss_giou_0_unscaled: 0.1331 (0.1396)  cardinality_error_0_unscaled: 277.1875 (275.1893)  loss_ce_1_unscaled: 0.4785 (0.4587)  loss_bbox_1_unscaled: 0.0222 (0.0303)  loss_giou_1_unscaled: 0.1280 (0.1395)  cardinality_error_1_unscaled: 286.1250 (283.5928)  loss_ce_enc_unscaled: 0.4883 (0.4800)  loss_bbox_enc_unscaled: 0.0302 (0.0351)  loss_giou_enc_unscaled: 0.1503 (0.1521)  cardinality_error_enc_unscaled: 283.3125 (283.0625)
# Accumulating evaluation results...
# DONE (t=2.87s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.749
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.942
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.831
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.672
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.821
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.817
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.758
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.864
# Grad accum steps:  4
# Total batch size:  64
# LENGTH OF DATA LOADER: 114
# Epoch: [67]  [  0/114]  eta: 0:56:58  lr: 0.000100  class_error: 0.00  loss: 2.4732 (2.4732)  loss_ce: 0.3169 (0.3169)  loss_bbox: 0.1264 (0.1264)  loss_giou: 0.1552 (0.1552)  loss_ce_0: 0.3072 (0.3072)  loss_bbox_0: 0.1216 (0.1216)  loss_giou_0: 0.1559 (0.1559)  loss_ce_1: 0.3142 (0.3142)  loss_bbox_1: 0.1209 (0.1209)  loss_giou_1: 0.1545 (0.1545)  loss_ce_enc: 0.3607 (0.3607)  loss_bbox_enc: 0.1468 (0.1468)  loss_giou_enc: 0.1929 (0.1929)  loss_ce_unscaled: 0.3169 (0.3169)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0253 (0.0253)  loss_giou_unscaled: 0.0776 (0.0776)  cardinality_error_unscaled: 3849.4375 (3849.4375)  loss_ce_0_unscaled: 0.3072 (0.3072)  loss_bbox_0_unscaled: 0.0243 (0.0243)  loss_giou_0_unscaled: 0.0779 (0.0779)  cardinality_error_0_unscaled: 3758.0000 (3758.0000)  loss_ce_1_unscaled: 0.3142 (0.3142)  loss_bbox_1_unscaled: 0.0242 (0.0242)  loss_giou_1_unscaled: 0.0773 (0.0773)  cardinality_error_1_unscaled: 3781.6250 (3781.6250)  loss_ce_enc_unscaled: 0.3607 (0.3607)  loss_bbox_enc_unscaled: 0.0294 (0.0294)  loss_giou_enc_unscaled: 0.0964 (0.0964)  cardinality_error_enc_unscaled: 3790.3125 (3790.3125)  time: 29.9845  data: 27.3475  max mem: 12894
# Epoch: [67]  [ 10/114]  eta: 0:09:00  lr: 0.000100  class_error: 0.00  loss: 2.3801 (2.3872)  loss_ce: 0.2993 (0.2908)  loss_bbox: 0.1066 (0.1014)  loss_giou: 0.1552 (0.1605)  loss_ce_0: 0.2985 (0.2952)  loss_bbox_0: 0.1216 (0.1074)  loss_giou_0: 0.1661 (0.1669)  loss_ce_1: 0.2924 (0.2880)  loss_bbox_1: 0.1209 (0.1060)  loss_giou_1: 0.1558 (0.1644)  loss_ce_enc: 0.3553 (0.3544)  loss_bbox_enc: 0.1468 (0.1490)  loss_giou_enc: 0.2060 (0.2031)  loss_ce_unscaled: 0.2993 (0.2908)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0213 (0.0203)  loss_giou_unscaled: 0.0776 (0.0803)  cardinality_error_unscaled: 3824.7500 (3818.0000)  loss_ce_0_unscaled: 0.2985 (0.2952)  loss_bbox_0_unscaled: 0.0243 (0.0215)  loss_giou_0_unscaled: 0.0831 (0.0834)  cardinality_error_0_unscaled: 3611.6875 (3593.8182)  loss_ce_1_unscaled: 0.2924 (0.2880)  loss_bbox_1_unscaled: 0.0242 (0.0212)  loss_giou_1_unscaled: 0.0779 (0.0822)  cardinality_error_1_unscaled: 3721.9375 (3694.3409)  loss_ce_enc_unscaled: 0.3553 (0.3544)  loss_bbox_enc_unscaled: 0.0294 (0.0298)  loss_giou_enc_unscaled: 0.1030 (0.1016)  cardinality_error_enc_unscaled: 3688.6250 (3613.4205)  time: 5.2008  data: 2.5020  max mem: 12894
# Epoch: [67]  [ 20/114]  eta: 0:06:13  lr: 0.000100  class_error: 0.00  loss: 2.3801 (2.4304)  loss_ce: 0.2906 (0.2938)  loss_bbox: 0.0970 (0.1065)  loss_giou: 0.1618 (0.1651)  loss_ce_0: 0.2985 (0.3013)  loss_bbox_0: 0.1014 (0.1084)  loss_giou_0: 0.1661 (0.1685)  loss_ce_1: 0.2924 (0.2947)  loss_bbox_1: 0.1007 (0.1089)  loss_giou_1: 0.1685 (0.1673)  loss_ce_enc: 0.3537 (0.3574)  loss_bbox_enc: 0.1383 (0.1521)  loss_giou_enc: 0.2054 (0.2063)  loss_ce_unscaled: 0.2906 (0.2938)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0194 (0.0213)  loss_giou_unscaled: 0.0809 (0.0825)  cardinality_error_unscaled: 3807.9375 (3811.8839)  loss_ce_0_unscaled: 0.2985 (0.3013)  loss_bbox_0_unscaled: 0.0203 (0.0217)  loss_giou_0_unscaled: 0.0831 (0.0843)  cardinality_error_0_unscaled: 3597.6875 (3577.9613)  loss_ce_1_unscaled: 0.2924 (0.2947)  loss_bbox_1_unscaled: 0.0201 (0.0218)  loss_giou_1_unscaled: 0.0843 (0.0836)  cardinality_error_1_unscaled: 3694.1875 (3686.4048)  loss_ce_enc_unscaled: 0.3537 (0.3574)  loss_bbox_enc_unscaled: 0.0277 (0.0304)  loss_giou_enc_unscaled: 0.1027 (0.1031)  cardinality_error_enc_unscaled: 3674.8125 (3631.5804)  time: 2.6685  data: 0.0177  max mem: 12894
# ...
# Test:  [60/68]  eta: 0:00:06  class_error: 4.55  loss: 3.3512 (3.5421)  loss_ce: 0.4688 (0.4594)  loss_bbox: 0.1209 (0.1466)  loss_giou: 0.2197 (0.2620)  loss_ce_0: 0.4824 (0.4628)  loss_bbox_0: 0.1215 (0.1531)  loss_giou_0: 0.2223 (0.2697)  loss_ce_1: 0.4727 (0.4610)  loss_bbox_1: 0.1216 (0.1464)  loss_giou_1: 0.2171 (0.2621)  loss_ce_enc: 0.4609 (0.4683)  loss_bbox_enc: 0.1366 (0.1665)  loss_giou_enc: 0.2490 (0.2841)  loss_ce_unscaled: 0.4688 (0.4594)  class_error_unscaled: 0.0000 (1.2359)  loss_bbox_unscaled: 0.0242 (0.0293)  loss_giou_unscaled: 0.1098 (0.1310)  cardinality_error_unscaled: 290.6875 (290.3371)  loss_ce_0_unscaled: 0.4824 (0.4628)  loss_bbox_0_unscaled: 0.0243 (0.0306)  loss_giou_0_unscaled: 0.1112 (0.1349)  cardinality_error_0_unscaled: 272.1250 (272.8350)  loss_ce_1_unscaled: 0.4727 (0.4610)  loss_bbox_1_unscaled: 0.0243 (0.0293)  loss_giou_1_unscaled: 0.1085 (0.1311)  cardinality_error_1_unscaled: 280.1250 (280.4436)  loss_ce_enc_unscaled: 0.4609 (0.4683)  loss_bbox_enc_unscaled: 0.0273 (0.0333)  loss_giou_enc_unscaled: 0.1245 (0.1420)  cardinality_error_enc_unscaled: 285.1250 (281.4252)  time: 0.4416  data: 0.0325  max mem: 12894
# Test:  [67/68]  eta: 0:00:00  class_error: 0.00  loss: 3.4747 (3.6141)  loss_ce: 0.5039 (0.4671)  loss_bbox: 0.1303 (0.1486)  loss_giou: 0.2604 (0.2716)  loss_ce_0: 0.5312 (0.4698)  loss_bbox_0: 0.1313 (0.1544)  loss_giou_0: 0.2738 (0.2786)  loss_ce_1: 0.4922 (0.4687)  loss_bbox_1: 0.1251 (0.1485)  loss_giou_1: 0.2595 (0.2716)  loss_ce_enc: 0.4922 (0.4747)  loss_bbox_enc: 0.1449 (0.1672)  loss_giou_enc: 0.2971 (0.2932)  loss_ce_unscaled: 0.5039 (0.4671)  class_error_unscaled: 0.0000 (1.2219)  loss_bbox_unscaled: 0.0261 (0.0297)  loss_giou_unscaled: 0.1302 (0.1358)  cardinality_error_unscaled: 292.5000 (290.6287)  loss_ce_0_unscaled: 0.5312 (0.4698)  loss_bbox_0_unscaled: 0.0263 (0.0309)  loss_giou_0_unscaled: 0.1369 (0.1393)  cardinality_error_0_unscaled: 274.8125 (273.4072)  loss_ce_1_unscaled: 0.4922 (0.4687)  loss_bbox_1_unscaled: 0.0250 (0.0297)  loss_giou_1_unscaled: 0.1297 (0.1358)  cardinality_error_1_unscaled: 280.9375 (280.6333)  loss_ce_enc_unscaled: 0.4922 (0.4747)  loss_bbox_enc_unscaled: 0.0290 (0.0334)  loss_giou_enc_unscaled: 0.1485 (0.1466)  cardinality_error_enc_unscaled: 284.9375 (281.7252)  time: 0.4185  data: 0.0300  max mem: 12894
# Test: Total time: 0:00:53 (0.7802 s / it)
# Averaged stats: class_error: 0.00  loss: 3.4747 (3.6141)  loss_ce: 0.5039 (0.4671)  loss_bbox: 0.1303 (0.1486)  loss_giou: 0.2604 (0.2716)  loss_ce_0: 0.5312 (0.4698)  loss_bbox_0: 0.1313 (0.1544)  loss_giou_0: 0.2738 (0.2786)  loss_ce_1: 0.4922 (0.4687)  loss_bbox_1: 0.1251 (0.1485)  loss_giou_1: 0.2595 (0.2716)  loss_ce_enc: 0.4922 (0.4747)  loss_bbox_enc: 0.1449 (0.1672)  loss_giou_enc: 0.2971 (0.2932)  loss_ce_unscaled: 0.5039 (0.4671)  class_error_unscaled: 0.0000 (1.2219)  loss_bbox_unscaled: 0.0261 (0.0297)  loss_giou_unscaled: 0.1302 (0.1358)  cardinality_error_unscaled: 292.5000 (290.6287)  loss_ce_0_unscaled: 0.5312 (0.4698)  loss_bbox_0_unscaled: 0.0263 (0.0309)  loss_giou_0_unscaled: 0.1369 (0.1393)  cardinality_error_0_unscaled: 274.8125 (273.4072)  loss_ce_1_unscaled: 0.4922 (0.4687)  loss_bbox_1_unscaled: 0.0250 (0.0297)  loss_giou_1_unscaled: 0.1297 (0.1358)  cardinality_error_1_unscaled: 280.9375 (280.6333)  loss_ce_enc_unscaled: 0.4922 (0.4747)  loss_bbox_enc_unscaled: 0.0290 (0.0334)  loss_giou_enc_unscaled: 0.1485 (0.1466)  cardinality_error_enc_unscaled: 284.9375 (281.7252)
# Accumulating evaluation results...
# DONE (t=2.92s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.751
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.942
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.680
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.766
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.824
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.576
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.772
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.877
# Training time 4:07:54
# Results saved to output\results.json
# Test:  [ 0/25]  eta: 0:10:21  class_error: 0.00  loss: 3.5247 (3.5247)  loss_ce: 0.4512 (0.4512)  loss_bbox: 0.0986 (0.0986)  loss_giou: 0.3235 (0.3235)  loss_ce_0: 0.4453 (0.4453)  loss_bbox_0: 0.0988 (0.0988)  loss_giou_0: 0.3211 (0.3211)  loss_ce_1: 0.4473 (0.4473)  loss_bbox_1: 0.0981 (0.0981)  loss_giou_1: 0.3210 (0.3210)  loss_ce_enc: 0.4785 (0.4785)  loss_bbox_enc: 0.1037 (0.1037)  loss_giou_enc: 0.3376 (0.3376)  loss_ce_unscaled: 0.4512 (0.4512)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0197 (0.0197)  loss_giou_unscaled: 0.1617 (0.1617)  cardinality_error_unscaled: 288.5000 (288.5000)  loss_ce_0_unscaled: 0.4453 (0.4453)  loss_bbox_0_unscaled: 0.0198 (0.0198)  loss_giou_0_unscaled: 0.1605 (0.1605)  cardinality_error_0_unscaled: 260.1875 (260.1875)  loss_ce_1_unscaled: 0.4473 (0.4473)  loss_bbox_1_unscaled: 0.0196 (0.0196)  loss_giou_1_unscaled: 0.1605 (0.1605)  cardinality_error_1_unscaled: 265.6875 (265.6875)  loss_ce_enc_unscaled: 0.4785 (0.4785)  loss_bbox_enc_unscaled: 0.0207 (0.0207)  loss_giou_enc_unscaled: 0.1688 (0.1688)  cardinality_error_enc_unscaled: 263.0000 (263.0000)  time: 24.8417  data: 24.1638  max mem: 12894
# Test:  [10/25]  eta: 0:00:39  class_error: 0.00  loss: 3.6336 (3.5252)  loss_ce: 0.4512 (0.4241)  loss_bbox: 0.1342 (0.1649)  loss_giou: 0.3235 (0.2736)  loss_ce_0: 0.4473 (0.4309)  loss_bbox_0: 0.1331 (0.1663)  loss_giou_0: 0.3211 (0.2752)  loss_ce_1: 0.4473 (0.4244)  loss_bbox_1: 0.1332 (0.1640)  loss_giou_1: 0.3210 (0.2747)  loss_ce_enc: 0.4746 (0.4540)  loss_bbox_enc: 0.1444 (0.1825)  loss_giou_enc: 0.3376 (0.2907)  loss_ce_unscaled: 0.4512 (0.4241)  class_error_unscaled: 0.0000 (0.5051)  loss_bbox_unscaled: 0.0268 (0.0330)  loss_giou_unscaled: 0.1617 (0.1368)  cardinality_error_unscaled: 292.6250 (291.9773)  loss_ce_0_unscaled: 0.4473 (0.4309)  loss_bbox_0_unscaled: 0.0266 (0.0333)  loss_giou_0_unscaled: 0.1605 (0.1376)  cardinality_error_0_unscaled: 273.3750 (270.8977)  loss_ce_1_unscaled: 0.4473 (0.4244)  loss_bbox_1_unscaled: 0.0266 (0.0328)  loss_giou_1_unscaled: 0.1605 (0.1374)  cardinality_error_1_unscaled: 273.3750 (272.0852)  loss_ce_enc_unscaled: 0.4746 (0.4540)  loss_bbox_enc_unscaled: 0.0289 (0.0365)  loss_giou_enc_unscaled: 0.1688 (0.1453)  cardinality_error_enc_unscaled: 274.6250 (273.2727)  time: 2.6112  data: 2.2217  max mem: 12894
# Test:  [20/25]  eta: 0:00:07  class_error: 0.00  loss: 3.3525 (3.3768)  loss_ce: 0.4141 (0.4179)  loss_bbox: 0.1245 (0.1516)  loss_giou: 0.2370 (0.2506)  loss_ce_0: 0.4473 (0.4346)  loss_bbox_0: 0.1330 (0.1514)  loss_giou_0: 0.2357 (0.2535)  loss_ce_1: 0.4277 (0.4212)  loss_bbox_1: 0.1182 (0.1509)  loss_giou_1: 0.2404 (0.2496)  loss_ce_enc: 0.4434 (0.4518)  loss_bbox_enc: 0.1444 (0.1720)  loss_giou_enc: 0.2531 (0.2716)  loss_ce_unscaled: 0.4141 (0.4179)  class_error_unscaled: 0.0000 (1.3555)  loss_bbox_unscaled: 0.0249 (0.0303)  loss_giou_unscaled: 0.1185 (0.1253)  cardinality_error_unscaled: 293.0625 (292.7946)  loss_ce_0_unscaled: 0.4473 (0.4346)  loss_bbox_0_unscaled: 0.0266 (0.0303)  loss_giou_0_unscaled: 0.1178 (0.1267)  cardinality_error_0_unscaled: 275.8125 (274.9554)  loss_ce_1_unscaled: 0.4277 (0.4212)  loss_bbox_1_unscaled: 0.0236 (0.0302)  loss_giou_1_unscaled: 0.1202 (0.1248)  cardinality_error_1_unscaled: 274.2500 (273.7946)  loss_ce_enc_unscaled: 0.4434 (0.4518)  loss_bbox_enc_unscaled: 0.0289 (0.0344)  loss_giou_enc_unscaled: 0.1266 (0.1358)  cardinality_error_enc_unscaled: 278.7500 (277.7381)  time: 0.4011  data: 0.0308  max mem: 12894
# Test:  [24/25]  eta: 0:00:01  class_error: 0.00  loss: 3.5488 (3.5550)  loss_ce: 0.4160 (0.4397)  loss_bbox: 0.1456 (0.1541)  loss_giou: 0.2504 (0.2697)  loss_ce_0: 0.4512 (0.4567)  loss_bbox_0: 0.1393 (0.1563)  loss_giou_0: 0.2513 (0.2754)  loss_ce_1: 0.4316 (0.4427)  loss_bbox_1: 0.1460 (0.1536)  loss_giou_1: 0.2481 (0.2690)  loss_ce_enc: 0.4648 (0.4685)  loss_bbox_enc: 0.1531 (0.1755)  loss_giou_enc: 0.2712 (0.2937)  loss_ce_unscaled: 0.4160 (0.4397)  class_error_unscaled: 0.0000 (1.3125)  loss_bbox_unscaled: 0.0291 (0.0308)  loss_giou_unscaled: 0.1252 (0.1349)  cardinality_error_unscaled: 293.1250 (293.0725)  loss_ce_0_unscaled: 0.4512 (0.4567)  loss_bbox_0_unscaled: 0.0279 (0.0313)  loss_giou_0_unscaled: 0.1257 (0.1377)  cardinality_error_0_unscaled: 275.8125 (274.7675)  loss_ce_1_unscaled: 0.4316 (0.4427)  loss_bbox_1_unscaled: 0.0292 (0.0307)  loss_giou_1_unscaled: 0.1240 (0.1345)  cardinality_error_1_unscaled: 274.2500 (274.2350)  loss_ce_enc_unscaled: 0.4648 (0.4685)  loss_bbox_enc_unscaled: 0.0306 (0.0351)  loss_giou_enc_unscaled: 0.1356 (0.1469)  cardinality_error_enc_unscaled: 277.4375 (277.0025)  time: 0.3875  data: 0.0290  max mem: 12894
# Test: Total time: 0:00:35 (1.4213 s / it)
# Averaged stats: class_error: 0.00  loss: 3.5488 (3.5550)  loss_ce: 0.4160 (0.4397)  loss_bbox: 0.1456 (0.1541)  loss_giou: 0.2504 (0.2697)  loss_ce_0: 0.4512 (0.4567)  loss_bbox_0: 0.1393 (0.1563)  loss_giou_0: 0.2513 (0.2754)  loss_ce_1: 0.4316 (0.4427)  loss_bbox_1: 0.1460 (0.1536)  loss_giou_1: 0.2481 (0.2690)  loss_ce_enc: 0.4648 (0.4685)  loss_bbox_enc: 0.1531 (0.1755)  loss_giou_enc: 0.2712 (0.2937)  loss_ce_unscaled: 0.4160 (0.4397)  class_error_unscaled: 0.0000 (1.3125)  loss_bbox_unscaled: 0.0291 (0.0308)  loss_giou_unscaled: 0.1252 (0.1349)  cardinality_error_unscaled: 293.1250 (293.0725)  loss_ce_0_unscaled: 0.4512 (0.4567)  loss_bbox_0_unscaled: 0.0279 (0.0313)  loss_giou_0_unscaled: 0.1257 (0.1377)  cardinality_error_0_unscaled: 275.8125 (274.7675)  loss_ce_1_unscaled: 0.4316 (0.4427)  loss_bbox_1_unscaled: 0.0292 (0.0307)  loss_giou_1_unscaled: 0.1240 (0.1345)  cardinality_error_1_unscaled: 274.2500 (274.2350)  loss_ce_enc_unscaled: 0.4648 (0.4685)  loss_bbox_enc_unscaled: 0.0306 (0.0351)  loss_giou_enc_unscaled: 0.1356 (0.1469)  cardinality_error_enc_unscaled: 277.4375 (277.0025)
# Accumulating evaluation results...
# DONE (t=0.88s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.748
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.943
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.832
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.712
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.752
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.782
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.872
# Test results: {'class_error': 1.3125442504882812, 'loss': 3.5550099849700927, 'loss_ce': 0.4397265625, 'loss_bbox': 0.15407830387353896, 'loss_giou': 0.2697170251607895, 'loss_ce_0': 0.45671875, 'loss_bbox_0': 0.15632737755775453, 'loss_giou_0': 0.27538094103336336, 'loss_ce_1': 0.442734375, 'loss_bbox_1': 0.1535714888572693, 'loss_giou_1': 0.26898753046989443, 'loss_ce_enc': 0.468515625, 'loss_bbox_enc': 0.1755293571949005, 'loss_giou_enc': 0.29372266709804534, 'loss_ce_unscaled': 0.4397265625, 'class_error_unscaled': 1.3125442504882812, 'loss_bbox_unscaled': 0.03081566095352173, 'loss_giou_unscaled': 0.13485851258039475, 'cardinality_error_unscaled': 293.0725, 'loss_ce_0_unscaled': 0.45671875, 'loss_bbox_0_unscaled': 0.031265475787222385, 'loss_giou_0_unscaled': 0.13769047051668168, 'cardinality_error_0_unscaled': 274.7675, 'loss_ce_1_unscaled': 0.442734375, 'loss_bbox_1_unscaled': 0.030714297592639925, 'loss_giou_1_unscaled': 0.13449376523494722, 'cardinality_error_1_unscaled': 274.235, 'loss_ce_enc_unscaled': 0.468515625, 'loss_bbox_enc_unscaled': 0.03510587140917778, 'loss_giou_enc_unscaled': 0.14686133354902267, 'cardinality_error_enc_unscaled': 277.0025, 'results_json': {'class_map': [{'class': 'Glioma', 'map@50:95': 0.695147162199419, 'map@50': 0.9188513802729347, 'precision': 0.9347826086956522, 'recall': 0.85}, {'class': 'Meningioma', 'map@50:95': 0.8377867185492349, 'map@50': 0.9823028079135459, 'precision': 1.0, 'recall': 0.85}, {'class': 'No Tumor', 'map@50:95': 0.8342472354807745, 'map@50': 1.0, 'precision': 1.0, 'recall': 0.85}, {'class': 'Pituitary', 'map@50:95': 0.6239769741945788, 'map@50': 0.8707855534057617, 'precision': 0.9310344827586207, 'recall': 0.85}, {'class': 'all', 'map@50:95': 0.7477895226060018, 'map@50': 0.9429849353980606, 'precision': 0.9664542728635682, 'recall': 0.85}], 'map': 0.9429849353980606, 'precision': 0.9664542728635682, 'recall': 0.85}, 'coco_eval_bbox': [0.7477895226060018, 0.9429849353980606, 0.8318787433687265, 0.3164466446644664, 0.7119986755701755, 0.8020227026185218, 0.7518327228870403, 0.8151268949785232, 0.8153583764600046, 0.4166666666666667, 0.7816813711975004, 0.8716223924380703]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 31
#      28 model.callbacks["on_train_end"].append(on_train_end)
#      30 # Now train / resume
# ---> 31 model.train(
#      32     dataset_dir=dataset_dir,
#      33     epochs=target_epochs,
#      34     batch_size=batch_size,
#      35     lr=lr,
#      36     resume=checkpoint_path  # pass checkpoint to resume
#      37 )
#      39 # Finally, save model
#      40 model.save("rf_detr_small_resumed_final.pt")
#
# File D:\2. Tufail\28. Complete Solar Panel yolov8\1. Brain Tumor\RF-DETR\venv\lib\site-packages\rfdetr\detr.py:83, in RFDETR.train(self, **kwargs)
#      79 """
#      80 Train an RF-DETR model.
#      81 """
#      82 config = self.get_train_config(**kwargs)
# ---> 83 self.train_from_config(config, **kwargs)
#
# File D:\2. Tufail\28. Complete Solar Panel yolov8\1. Brain Tumor\RF-DETR\venv\lib\site-packages\rfdetr\detr.py:191, in RFDETR.train_from_config(self, config, **kwargs)
#     182     early_stopping_callback = EarlyStoppingCallback(
#     183         model=self.model,
#     184         patience=config.early_stopping_patience,
#    (...)
#     187         segmentation_head=config.segmentation_head
#     188     )
#     189     self.callbacks["on_fit_epoch_end"].append(early_stopping_callback.update)
# --> 191 self.model.train(
#     192     **all_kwargs,
#     193     callbacks=self.callbacks,
#     194 )
#
# File D:\2. Tufail\28. Complete Solar Panel yolov8\1. Brain Tumor\RF-DETR\venv\lib\site-packages\rfdetr\main.py:517, in Model.train(self, callbacks, **kwargs)
#     514         json.dump(results, f)
#     516 for callback in callbacks["on_train_end"]:
# --> 517     callback()
#
# TypeError: on_train_end() missing 1 required positional argument: 'data'
